# %%
# %matplotlib inline
import matplotlib.pyplot as plt 
import numpy as np
import pandas as pd

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3,4,5])

# %%
x = [1,2,3,4]
y=[7,54,-1,101]
plt.plot(x,y)

# %%
#1st method
fig = plt.figure()
ax = fig.add_subplot()
plt.show()

# %%
#2nd method
fig = plt.figure()
axe = fig.add_axes([1,1,1,1])
axe.plot(x,y)
plt.show()

# %%
# 3rd method (used)
fig,axe = plt.subplots()
axe.plot(x,y)
